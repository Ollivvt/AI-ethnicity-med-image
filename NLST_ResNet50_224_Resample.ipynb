# %%
import pandas as pd
import numpy as np
import os
import pydicom
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# %%
# Load the CSV file
data_path = '/mnt/win_share/GitHub/AI-ethnicity-med-image/data/axial_lung_ct_images.csv'
df = pd.read_csv(data_path)

# %%
# Convert any Windows-style paths to Unix-style paths
df['File Location'] = df['File Location'].apply(lambda x: x.replace("\\", "/"))

# %%
# Group by 'Subject ID' to handle multiple images per patient
grouped = df.groupby('Subject ID')

# Randomly select one image per patient
df_single_image_per_patient = grouped.apply(lambda x: x.sample(1, random_state=42)).reset_index(drop=True)

# Label mapping for converting race categories to integers
label_mapping = {
    "White": 0,
    "Black or African-American": 1,
    "Asian": 2,
    "American Indian or Alaskan Native": 3,
    "Native Hawaiian or Other Pacific Islander": 4
}

# Convert the 'Patient Race' to integer labels
df_single_image_per_patient['Race_Label'] = df_single_image_per_patient['Patient Race'].map(label_mapping)

# %%
num_patients = df_single_image_per_patient['Subject ID'].nunique()
num_images = len(df_single_image_per_patient)

# Print the results
print(f"Number of unique patients: {num_patients}")
print(f"Number of images after selecting one per patient: {num_images}")
# Out:
# Number of unique patients: 15639
# Number of images after selecting one per patient: 15639

# %%
# Downsampling and Upsampling Strategy
desired_samples = {
    "White": 2000,  # Downsample to 2000
    "Black or African-American": 1135,  # Upsample
    "Asian": 1135,  # Upsample
    "American Indian or Alaskan Native": 1135,  # Upsample
    "Native Hawaiian or Other Pacific Islander": 1135  # Upsample
}

resampled_df = pd.DataFrame()

for race, target_count in desired_samples.items():
    race_df = df_single_image_per_patient[df_single_image_per_patient['Patient Race'] == race]
    
    if len(race_df) > target_count:
        resampled_df = pd.concat([resampled_df, race_df.sample(target_count, random_state=42)])
    else:
        resampled_df = pd.concat([resampled_df, race_df.sample(target_count, replace=True, random_state=42)])

resampled_df = resampled_df.reset_index(drop=True)

# %%
# Check class distribution
print("Class distribution after resampling:")
print(resampled_df['Patient Race'].value_counts())
# Out:
# Class distribution after resampling:
# Patient Race
# White                                        2000
# Black or African-American                    1135
# Asian                                        1135
# American Indian or Alaskan Native            1135
# Native Hawaiian or Other Pacific Islander    1135
# Name: count, dtype: int64

# %%
# Train-validation split
X_train, X_val, y_train, y_val = train_test_split(
    resampled_df['File Location'],
    resampled_df['Race_Label'],
    test_size=0.2,
    stratify=resampled_df['Race_Label'],
    random_state=42
)

# %%
# Change to current directory
os.chdir('/media/yu-tingtseng_sa/16TB IronWolf Pro/Data/NLST/Radiology CT Images/manifest-NLST_allCT')
print(os.getcwd())
# Out:
# /media/yu-tingtseng_sa/16TB IronWolf Pro/Data/NLST/Radiology CT Images/manifest-NLST_allCT

# %%
# Preprocess images for model input
def preprocess_images(file_paths, labels):
    image_data = []
    processed_labels = []
    
    # Ensure only one image per patient (process the first DICOM file found)
    for file_path, label in zip(file_paths, labels):
        dicom_folder = file_path  # Path to the folder containing DICOM images
        dicom_files = [f for f in os.listdir(dicom_folder) if f.endswith('.dcm')]  # List DICOM files
        
        if dicom_files:
            dicom_file = dicom_files[0]  # Select the first DICOM file only
            dicom_path = os.path.join(dicom_folder, dicom_file)
            ds = pydicom.dcmread(dicom_path)  # Read the DICOM file
            img_array = ds.pixel_array  # Extract pixel array

            # Normalize the image
            img_array = img_array / np.max(img_array)  # Normalize to [0, 1]

            # Resize the image
            img = Image.fromarray(img_array)  # Convert to PIL image
            img = img.resize((224, 224))  # Resize to 224x224 pixels
            img_array_resized = np.array(img)  # Convert back to numpy array

            # Convert grayscale image to 3-channel RGB by repeating the single channel 3 times
            img_array_rgb = np.stack([img_array_resized] * 3, axis=-1)

            image_data.append(img_array_rgb)
            processed_labels.append(label)  # Append the corresponding label
    
    return np.array(image_data), np.array(processed_labels)

# %%
# Preprocess images for training and validation sets (ensure 1 image per patient)
X_train_images, y_train_labels = preprocess_images(X_train, y_train)
X_val_images, y_val_labels = preprocess_images(X_val, y_val)

# %%
# Check the number of images
num_train_images = X_train_images.shape[0]
num_val_images = X_val_images.shape[0]

print(f"Number of training images: {num_train_images}")
print(f"Number of validation images: {num_val_images}")
print(f"Number of training labels: {len(y_train_labels)}")
print(f"Number of validation labels: {len(y_val_labels)}")
# Out:
# Number of training images: 5232
# Number of validation images: 1308
# Number of training labels: 5232
# Number of validation labels: 1308

# %%
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: []

# %%
# Load the pre-trained EfficientNetB0 model without the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of the pre-trained model
x = base_model.output
x = Flatten()(x)  # Flatten the output
x = Dense(128, activation='relu')(x)  # Fully connected layer
output = Dense(len(label_mapping), activation='softmax')(x)  # Output layer with softmax activation for multiclass classification

# %%
# Create the complete model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the generator
history = model.fit(X_train_images, 
                    y_train_labels, 
                    validation_data=(X_val_images, y_val_labels), 
                    epochs=50, 
                    batch_size=32)

# Save the model
# model.save('ethnicity_classification_model.h5')
# Out:
# Epoch 1/50
# 164/164 [==============================] - 86s 515ms/step - loss: 1.2368 - accuracy: 0.4534 - val_loss: 1.2149 - val_accuracy: 0.4580
# Epoch 2/50
# 164/164 [==============================] - 85s 517ms/step - loss: 1.1688 - accuracy: 0.4922 - val_loss: 1.1530 - val_accuracy: 0.4885
# Epoch 3/50
# 164/164 [==============================] - 85s 519ms/step - loss: 1.1341 - accuracy: 0.5109 - val_loss: 1.1284 - val_accuracy: 0.5069
# Epoch 4/50
# 164/164 [==============================] - 84s 513ms/step - loss: 1.0913 - accuracy: 0.5409 - val_loss: 1.1075 - val_accuracy: 0.5145
# Epoch 5/50
# 164/164 [==============================] - 86s 526ms/step - loss: 1.0610 - accuracy: 0.5543 - val_loss: 1.1007 - val_accuracy: 0.5076
# Epoch 6/50
# 164/164 [==============================] - 87s 529ms/step - loss: 1.0463 - accuracy: 0.5577 - val_loss: 1.0553 - val_accuracy: 0.5405
# Epoch 7/50
# 164/164 [==============================] - 86s 525ms/step - loss: 1.0180 - accuracy: 0.5795 - val_loss: 1.0626 - val_accuracy: 0.5474
# Epoch 8/50
# 164/164 [==============================] - 82s 503ms/step - loss: 1.0123 - accuracy: 0.5782 - val_loss: 1.0405 - val_accuracy: 0.5382
# Epoch 9/50
# 164/164 [==============================] - 94s 571ms/step - loss: 0.9930 - accuracy: 0.5885 - val_loss: 0.9982 - val_accuracy: 0.5665
# Epoch 10/50
# 164/164 [==============================] - 126s 768ms/step - loss: 0.9794 - accuracy: 0.5837 - val_loss: 0.9929 - val_accuracy: 0.5787
# Epoch 11/50
# 164/164 [==============================] - 127s 776ms/step - loss: 0.9555 - accuracy: 0.6093 - val_loss: 0.9768 - val_accuracy: 0.5803
# Epoch 12/50
# 164/164 [==============================] - 115s 700ms/step - loss: 0.9386 - accuracy: 0.6296 - val_loss: 0.9755 - val_accuracy: 0.6070
# Epoch 13/50
# 164/164 [==============================] - 83s 509ms/step - loss: 0.9293 - accuracy: 0.6223 - val_loss: 0.9755 - val_accuracy: 0.5872
# Epoch 14/50
# 164/164 [==============================] - 85s 519ms/step - loss: 0.9189 - accuracy: 0.6370 - val_loss: 0.9417 - val_accuracy: 0.6063
# Epoch 15/50
# 164/164 [==============================] - 85s 516ms/step - loss: 0.9075 - accuracy: 0.6367 - val_loss: 0.9503 - val_accuracy: 0.6078
# Epoch 16/50
# 164/164 [==============================] - 84s 514ms/step - loss: 0.8954 - accuracy: 0.6512 - val_loss: 0.9128 - val_accuracy: 0.6453
# Epoch 17/50
# 164/164 [==============================] - 84s 512ms/step - loss: 0.8838 - accuracy: 0.6573 - val_loss: 0.9203 - val_accuracy: 0.6422
# Epoch 18/50
# 164/164 [==============================] - 84s 511ms/step - loss: 0.8701 - accuracy: 0.6600 - val_loss: 0.8974 - val_accuracy: 0.6521
# Epoch 19/50
# 164/164 [==============================] - 85s 519ms/step - loss: 0.8664 - accuracy: 0.6636 - val_loss: 0.8909 - val_accuracy: 0.6766
# Epoch 20/50
# 164/164 [==============================] - 85s 519ms/step - loss: 0.8571 - accuracy: 0.6734 - val_loss: 0.8790 - val_accuracy: 0.6537
# Epoch 21/50
# 164/164 [==============================] - 85s 517ms/step - loss: 0.8431 - accuracy: 0.6768 - val_loss: 0.8802 - val_accuracy: 0.6751
# Epoch 22/50
# 164/164 [==============================] - 87s 532ms/step - loss: 0.8364 - accuracy: 0.6823 - val_loss: 0.8930 - val_accuracy: 0.6292
# Epoch 23/50
# 164/164 [==============================] - 87s 529ms/step - loss: 0.8213 - accuracy: 0.6944 - val_loss: 0.9028 - val_accuracy: 0.5925
# Epoch 24/50
# 164/164 [==============================] - 86s 527ms/step - loss: 0.8167 - accuracy: 0.6902 - val_loss: 0.8460 - val_accuracy: 0.6858
# Epoch 25/50
# 164/164 [==============================] - 83s 504ms/step - loss: 0.8090 - accuracy: 0.7074 - val_loss: 0.8518 - val_accuracy: 0.6743
# Epoch 26/50
# 164/164 [==============================] - 83s 506ms/step - loss: 0.8003 - accuracy: 0.6986 - val_loss: 0.8415 - val_accuracy: 0.6667
# Epoch 27/50
# 164/164 [==============================] - 84s 513ms/step - loss: 0.7959 - accuracy: 0.7026 - val_loss: 0.8615 - val_accuracy: 0.6422
# Epoch 28/50
# 164/164 [==============================] - 84s 513ms/step - loss: 0.7797 - accuracy: 0.7139 - val_loss: 0.8120 - val_accuracy: 0.6820
# Epoch 29/50
# 164/164 [==============================] - 86s 522ms/step - loss: 0.7778 - accuracy: 0.7110 - val_loss: 0.8082 - val_accuracy: 0.6980
# Epoch 30/50
# 164/164 [==============================] - 84s 514ms/step - loss: 0.7678 - accuracy: 0.7278 - val_loss: 0.8184 - val_accuracy: 0.6888
# Epoch 31/50
# 164/164 [==============================] - 86s 523ms/step - loss: 0.7611 - accuracy: 0.7229 - val_loss: 0.8030 - val_accuracy: 0.6957
# Epoch 32/50
# 164/164 [==============================] - 86s 527ms/step - loss: 0.7572 - accuracy: 0.7297 - val_loss: 0.7943 - val_accuracy: 0.6873
# Epoch 33/50
# 164/164 [==============================] - 86s 522ms/step - loss: 0.7493 - accuracy: 0.7297 - val_loss: 0.8052 - val_accuracy: 0.6667
# Epoch 34/50
# 164/164 [==============================] - 86s 525ms/step - loss: 0.7445 - accuracy: 0.7338 - val_loss: 0.7900 - val_accuracy: 0.7041
# Epoch 35/50
# 164/164 [==============================] - 86s 528ms/step - loss: 0.7315 - accuracy: 0.7485 - val_loss: 0.7838 - val_accuracy: 0.7080
# Epoch 36/50
# 164/164 [==============================] - 86s 525ms/step - loss: 0.7244 - accuracy: 0.7487 - val_loss: 0.7665 - val_accuracy: 0.7248
# Epoch 37/50
# 164/164 [==============================] - 85s 518ms/step - loss: 0.7239 - accuracy: 0.7435 - val_loss: 0.7745 - val_accuracy: 0.6988
# Epoch 38/50
# 164/164 [==============================] - 85s 517ms/step - loss: 0.7128 - accuracy: 0.7527 - val_loss: 0.7539 - val_accuracy: 0.7332
# Epoch 39/50
# 164/164 [==============================] - 82s 501ms/step - loss: 0.7128 - accuracy: 0.7456 - val_loss: 0.7594 - val_accuracy: 0.7187
# Epoch 40/50
# 164/164 [==============================] - 86s 522ms/step - loss: 0.7043 - accuracy: 0.7573 - val_loss: 0.7446 - val_accuracy: 0.7294
# Epoch 41/50
# 164/164 [==============================] - 86s 525ms/step - loss: 0.6917 - accuracy: 0.7611 - val_loss: 0.7921 - val_accuracy: 0.6697
# Epoch 42/50
# 164/164 [==============================] - 85s 521ms/step - loss: 0.6921 - accuracy: 0.7555 - val_loss: 0.7845 - val_accuracy: 0.6743
# Epoch 43/50
# 164/164 [==============================] - 87s 530ms/step - loss: 0.6846 - accuracy: 0.7680 - val_loss: 0.7327 - val_accuracy: 0.7347
# Epoch 44/50
# 164/164 [==============================] - 86s 526ms/step - loss: 0.6786 - accuracy: 0.7716 - val_loss: 0.7401 - val_accuracy: 0.7164
# Epoch 45/50
# 164/164 [==============================] - 85s 517ms/step - loss: 0.6729 - accuracy: 0.7731 - val_loss: 0.7219 - val_accuracy: 0.7339
# Epoch 46/50
# 164/164 [==============================] - 86s 528ms/step - loss: 0.6699 - accuracy: 0.7662 - val_loss: 0.7175 - val_accuracy: 0.7408
# Epoch 47/50
# 164/164 [==============================] - 86s 528ms/step - loss: 0.6629 - accuracy: 0.7737 - val_loss: 0.7177 - val_accuracy: 0.7240
# Epoch 48/50
# 164/164 [==============================] - 85s 522ms/step - loss: 0.6625 - accuracy: 0.7661 - val_loss: 0.7193 - val_accuracy: 0.7248
# Epoch 49/50
# 164/164 [==============================] - 85s 520ms/step - loss: 0.6517 - accuracy: 0.7771 - val_loss: 0.6999 - val_accuracy: 0.7339
# Epoch 50/50
# 164/164 [==============================] - 85s 517ms/step - loss: 0.6461 - accuracy: 0.7773 - val_loss: 0.6915 - val_accuracy: 0.7576

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Make predictions on the validation set
y_pred = model.predict(X_val_images)

# Convert predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
# Out:
# 41/41 [==============================] - 16s 380ms/step

# %%
# Create a confusion matrix
cm = confusion_matrix(y_val_labels, y_pred_labels)

cma = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Define race labels
race_labels = ['W', 'B/AF', 'A', 'AI/AN', 'NH/PA']

# Calculate accuracy
accuracy = accuracy_score(y_val_labels, y_pred_labels)
print(f"Accuracy: {accuracy:.4f}")

# Plot the confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cma, annot=True, fmt='.2f', cmap='Blues', xticklabels=race_labels, yticklabels=race_labels)
plt.xlabel('Predicted Race')
plt.ylabel('True Race')
plt.title(f'Confusion Matrix - Ethnicity Classification (Accuracy: {accuracy:.2f})')
plt.show()
# Out:
# Accuracy: 0.7576

# %%
# Print a detailed classification report
print("Classification Report:")
print(classification_report(y_val_labels, y_pred_labels, target_names=label_mapping.keys(), zero_division=1))
# Out:
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                                     White       0.62      0.72      0.67       400
#                 Black or African-American       0.58      0.50      0.54       227
#                                     Asian       0.57      0.81      0.67       227
#         American Indian or Alaskan Native       0.87      0.69      0.77       227
# Native Hawaiian or Other Pacific Islander       0.87      0.55      0.67       227
#
#                                  accuracy                           0.67      1308
#                                 macro avg       0.70      0.66      0.66      1308
#                              weighted avg       0.69      0.67      0.67      1308
