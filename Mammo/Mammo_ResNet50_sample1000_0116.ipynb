# %% [markdown]
# - LCC/RCC pairs
# - Random 2000 images
# - Image Preprocessing
#     - Breast Cropping
#     - 224 x 224 pixels
# - Balanced datasets with 300 pairs of each classes

# %%
import os
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.utils import resample
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Conv2D
from tensorflow.keras.models import Model
import numpy as np
import cv2
from collections import Counter

# %%
# Load the dataset
csv_path = '/home/yu-tingtseng_sa/GitHub/AI-ethnicity-med-image/data/Mammo/All_XWalk_Outcome_cleaned.csv'
data = pd.read_csv(csv_path, sep=',', quotechar='"', low_memory=False)

# %%
# Define the correct base path
correct_base_path = "/mnt/data1"

# Replace 'Q:\\' with the correct base path and standardize separators
data['FilePath'] = data['FilePath'].str.replace(r"^Q:\\", correct_base_path + "/", regex=True)
data['FilePath'] = data['FilePath'].str.replace(r"\\\\|\\", "/", regex=True)  # Replace backslashes with forward slashes

# Debugging: Print sample paths to verify
# print(data['FilePath'].head())

# Filter out rows with invalid or missing FilePath
data = data.dropna(subset=['FilePath'])  # Remove rows with NaN in FilePath
data = data[data['FilePath'].apply(lambda x: isinstance(x, str))]  # Keep only string paths

# %%
# Map ethnicity to 3 classes
def map_ethnicity(ethnicity):
    mapping = {
        "BR": "White", "EE": "White", "FR": "White", "NE": "White", "SE": "White", "WE": "White",
        "EA": "Asian - East and Southeast",
        "SA": "Asian - South"
    }
    return mapping.get(ethnicity, "Other")

data['ethnicity'] = data['ethnicity'].apply(map_ethnicity)

# Filter for selected ethnicities
data = data[data['ethnicity'].isin(["White", "Asian - East and Southeast", "Asian - South"])]

# %%
# Randomly select about 2000 images
data_sample = data.sample(n=4000, random_state=42)

# Show the distribution of ethnicity
ethnicity_counts = data_sample['ethnicity'].value_counts()
plt.figure(figsize=(10, 6))
# plt.style.use('default')
plt.bar(ethnicity_counts.index, ethnicity_counts.values, color='orange')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.title('Distribution of Ethnicity')
plt.xticks(rotation=45)
plt.show()

# %%
def preprocess(pngPath, output_dir):
    img = cv2.imread(pngPath, cv2.IMREAD_GRAYSCALE)

    # Create a binary image for the breast by thresholding
    binary_img = cv2.threshold(img, 1, 255, cv2.THRESH_BINARY)[1].astype(np.uint8)

    # Find all the contours in the binary image
    contours, _ = cv2.findContours(binary_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        raise ValueError("No contours found.")
    largest_contour = max(contours, key=cv2.contourArea)

    # Create a mask for the breast region
    mask = np.zeros(img.shape, np.uint8)
    mask = cv2.fillPoly(mask, [largest_contour], 255)

    # Find the bounding box around the largest contour
    x, y, w, h = cv2.boundingRect(largest_contour)

    # Crop the image
    imgCropped = img[y:y+h, x:x+w]

    # Make the cropped image square by padding
    max_dim = max(w, h)
    padded_img = cv2.copyMakeBorder(
        imgCropped,
        top=(max_dim - h) // 2,
        bottom=(max_dim - h + 1) // 2,
        left=(max_dim - w) // 2,
        right=(max_dim - w + 1) // 2,
        borderType=cv2.BORDER_CONSTANT,
        value=0  # Background color (black)
    )

    # Save the processed image to a unique directory based on the original file path
    patient_dir = os.path.dirname(pngPath).replace("/", "_").replace("\\", "_")
    patient_output_dir = os.path.join(output_dir, patient_dir)
    os.makedirs(patient_output_dir, exist_ok=True)
    output_path = os.path.join(patient_output_dir, os.path.basename(pngPath))
    cv2.imwrite(output_path, imgCropped)
    cv2.imwrite(output_path, padded_img)

    return output_path

# %%
# Directory for saving preprocessed images
output_dir = "/tmp/processed_images"
os.makedirs(output_dir, exist_ok=True)

# Find valid LCC/RCC pairs and preprocess them
valid_filepaths = []
labels = []

for folder_path in data_sample['FilePath']:
    if os.path.exists(folder_path):
        all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]
        lcc_files = [f for f in all_files if "LCC" in f]
        rcc_files = [f for f in all_files if "RCC" in f]
        if lcc_files and rcc_files:
            try:
                # Ensure LCC is on the left and RCC is on the right
                lcc_cropped_path = preprocess(lcc_files[0], output_dir)
                rcc_cropped_path = preprocess(rcc_files[0], output_dir)
                valid_filepaths.append((lcc_cropped_path, rcc_cropped_path))

                # Extract patient_id from the file path and match it to get ethnicity
                patient_id = os.path.basename(os.path.dirname(folder_path))
                matching_rows = data_sample[data_sample['patient_id'] == patient_id]
                if matching_rows.empty:
                    print(f"Warning: No matching label found for patient_id {patient_id}. Skipping.")
                    continue
                label = matching_rows['ethnicity'].iloc[0]
                labels.append(label)
            except Exception as e:
                print(f"Error processing {folder_path}: {e}")

# Standardize image placement (left=LCC, right=RCC)
valid_filepaths = [(lcc, rcc) for lcc, rcc in valid_filepaths if "LCC" in lcc and "RCC" in rcc]

# Display count of valid pairs
print(f"Number of valid LCC/RCC pairs: {len(valid_filepaths)}")
print(f"Ethnicity distribution in valid pairs: {Counter(labels)}")
# Out:
# Number of valid LCC/RCC pairs: 3910
# Ethnicity distribution in valid pairs: Counter({'White': 2271, 'Asian - East and Southeast': 1378, 'Asian - South': 261})

# %% [markdown]
# ### LCC Only

# %%
# Preprocessing LCC images only
lcc_only_filepaths = []
lcc_only_labels = []

for folder_path in data_sample['FilePath']:
    if os.path.exists(folder_path):
        all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]
        lcc_files = [f for f in all_files if "LCC" in f]
        if lcc_files:
            try:
                lcc_cropped_path = preprocess(lcc_files[0], output_dir)
                lcc_only_filepaths.append(lcc_cropped_path)

                # Extract patient_id from the file path and match it to get ethnicity
                patient_id = os.path.basename(os.path.dirname(folder_path))
                matching_rows = data_sample[data_sample['patient_id'] == patient_id]
                if matching_rows.empty:
                    print(f"Warning: No matching label found for patient_id {patient_id}. Skipping.")
                    continue
                label = matching_rows['ethnicity'].iloc[0]
                lcc_only_labels.append(label)
            except Exception as e:
                print(f"Error processing {folder_path}: {e}")

# Display count of valid LCC-only images
# print(f"Number of valid LCC-only images: {len(lcc_only_filepaths)}")

# # Split LCC-only dataset into train/test datasets
# train_lcc_filepaths, test_lcc_filepaths, train_lcc_labels, test_lcc_labels = train_test_split(
#     lcc_only_filepaths, lcc_only_labels, test_size=0.2, stratify=lcc_only_labels, random_state=42
# )

# %%
# Count the number of LCC images in each group
lcc_counts = pd.Series(lcc_only_labels).value_counts()
print("LCC Image Counts by Group:")
print(lcc_counts)
# Out:
# LCC Image Counts by Group:
# White                         2276
# Asian - East and Southeast    1380
# Asian - South                  261
# Name: count, dtype: int64

# %%
# Downsample "White" class and upsample "Asian - South" class
white_indices = [i for i, label in enumerate(lcc_only_labels) if label == "White"]
asian_south_indices = [i for i, label in enumerate(lcc_only_labels) if label == "Asian - South"]
asian_east_indices = [i for i, label in enumerate(lcc_only_labels) if label == "Asian - East and Southeast"]

# Determine target size (same as Asian - East and Southeast)
target_size = 1600 # len(asian_east_indices)

# Downsample "White"
downsampled_white_indices = random.sample(white_indices, 1300)

# Upsample "Asian - South"
upsampled_asian_south_indices = resample(
    asian_south_indices,
    replace=True,
    n_samples=target_size,
    random_state=42
)

# Combine indices
final_indices = downsampled_white_indices + asian_east_indices + upsampled_asian_south_indices

# Create the balanced dataset
balanced_filepaths = [lcc_only_filepaths[i] for i in final_indices]
balanced_labels = [lcc_only_labels[i] for i in final_indices]

# Display count of balanced LCC-only images
print(f"Number of balanced LCC-only images: {len(balanced_filepaths)}")

# Split balanced LCC-only dataset into train/test datasets
train_lcc_filepaths, test_lcc_filepaths, train_lcc_labels, test_lcc_labels = train_test_split(
    balanced_filepaths, balanced_labels, test_size=0.2, stratify=balanced_labels, random_state=42
)
# Out:
# Number of balanced LCC-only images: 4280

# %%
# Convert LCC labels to numeric format
def encode_labels(labels):
    label_mapping = {label: idx for idx, label in enumerate(set(labels))}
    encoded_labels = [label_mapping[label] for label in labels]
    return encoded_labels, label_mapping

encoded_train_lcc_labels, lcc_label_mapping = encode_labels(train_lcc_labels)
encoded_test_lcc_labels = [lcc_label_mapping[label] for label in test_lcc_labels]

# Prepare LCC-only dataset for training
def create_lcc_dataset(filepaths, labels, augment=False):
    def load_lcc_image(filepath, augment):
        image = tf.image.decode_png(tf.io.read_file(filepath), channels=1)
        image = tf.image.resize(image, [224, 224])

        if augment:
            # Apply horizontal flipping randomly
            image = tf.image.random_flip_left_right(image)

        return image

    images = [load_lcc_image(filepath, augment) for filepath in filepaths]
    return tf.data.Dataset.from_tensor_slices((images, labels))

# Create LCC-only datasets with augmentation for training only
train_lcc_dataset = create_lcc_dataset(train_lcc_filepaths, encoded_train_lcc_labels, augment=True).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
test_lcc_dataset = create_lcc_dataset(test_lcc_filepaths, encoded_test_lcc_labels, augment=False).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# 2025-01-18 17:55:20.748980: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 687210496 exceeds 10% of free system memory.

# %%
# Build ResNet50 model with preprocessing for 1-channel input (LCC-only)
input_layer_lcc = Input(shape=(224, 224, 1))
base_model_lcc = ResNet50(weights=None, include_top=False, input_tensor=Conv2D(3, (1, 1), activation='linear')(input_layer_lcc))

# Add custom layers on top of ResNet50
x_lcc = base_model_lcc.output
x_lcc = GlobalAveragePooling2D()(x_lcc)
x_lcc = Dense(128, activation='relu')(x_lcc)
output_lcc = Dense(len(lcc_label_mapping), activation='softmax')(x_lcc)

model_lcc = Model(inputs=input_layer_lcc, outputs=output_lcc)

# Compile the model for LCC-only training
model_lcc.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model on LCC-only dataset
history_lcc = model_lcc.fit(
    train_lcc_dataset,
    validation_data=test_lcc_dataset,
    epochs=30,
    # callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)
# Out:
# Epoch 1/30
# 107/107 [==============================] - 194s 2s/step - loss: 1.2117 - accuracy: 0.4866 - val_loss: 1.2521 - val_accuracy: 0.3633
# Epoch 2/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.9201 - accuracy: 0.5593 - val_loss: 1.0968 - val_accuracy: 0.4825
# Epoch 3/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.8806 - accuracy: 0.5891 - val_loss: 1.6684 - val_accuracy: 0.4206
# Epoch 4/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.8494 - accuracy: 0.6063 - val_loss: 3.3615 - val_accuracy: 0.3271
# Epoch 5/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.8364 - accuracy: 0.6171 - val_loss: 1.4008 - val_accuracy: 0.4836
# Epoch 6/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.8182 - accuracy: 0.6346 - val_loss: 1.1369 - val_accuracy: 0.4977
# Epoch 7/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.7842 - accuracy: 0.6636 - val_loss: 1.4498 - val_accuracy: 0.3166
# Epoch 8/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.7356 - accuracy: 0.6887 - val_loss: 2.3026 - val_accuracy: 0.4030
# Epoch 9/30
# 107/107 [==============================] - 186s 2s/step - loss: 0.6955 - accuracy: 0.7068 - val_loss: 1.5742 - val_accuracy: 0.4579
# Epoch 10/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.6485 - accuracy: 0.7290 - val_loss: 1.2101 - val_accuracy: 0.5397
# Epoch 11/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.5687 - accuracy: 0.7693 - val_loss: 1.0241 - val_accuracy: 0.6227
# Epoch 12/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.4999 - accuracy: 0.7953 - val_loss: 1.7500 - val_accuracy: 0.4720
# Epoch 13/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.4607 - accuracy: 0.8140 - val_loss: 1.4684 - val_accuracy: 0.5596
# Epoch 14/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.4139 - accuracy: 0.8414 - val_loss: 1.3575 - val_accuracy: 0.6016
# Epoch 15/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.3639 - accuracy: 0.8560 - val_loss: 1.1748 - val_accuracy: 0.6554
# Epoch 16/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.3175 - accuracy: 0.8788 - val_loss: 1.1082 - val_accuracy: 0.6951
# Epoch 17/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.2820 - accuracy: 0.8937 - val_loss: 1.2498 - val_accuracy: 0.6752
# Epoch 18/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.2721 - accuracy: 0.8934 - val_loss: 2.1780 - val_accuracy: 0.5794
# Epoch 19/30
# 107/107 [==============================] - 182s 2s/step - loss: 0.2072 - accuracy: 0.9226 - val_loss: 1.1949 - val_accuracy: 0.6893
# Epoch 20/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.1795 - accuracy: 0.9299 - val_loss: 2.0829 - val_accuracy: 0.5689
# Epoch 21/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.1717 - accuracy: 0.9369 - val_loss: 3.5133 - val_accuracy: 0.4650
# Epoch 22/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.1339 - accuracy: 0.9489 - val_loss: 1.1293 - val_accuracy: 0.7173
# Epoch 23/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.1254 - accuracy: 0.9527 - val_loss: 1.7490 - val_accuracy: 0.7266
# Epoch 24/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.1444 - accuracy: 0.9512 - val_loss: 1.5417 - val_accuracy: 0.7114
# Epoch 25/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.1130 - accuracy: 0.9568 - val_loss: 1.2114 - val_accuracy: 0.7535
# Epoch 26/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.1296 - accuracy: 0.9524 - val_loss: 1.8023 - val_accuracy: 0.6484
# Epoch 27/30
# 107/107 [==============================] - 185s 2s/step - loss: 0.0811 - accuracy: 0.9682 - val_loss: 1.4160 - val_accuracy: 0.7395
# Epoch 28/30
# 107/107 [==============================] - 183s 2s/step - loss: 0.0795 - accuracy: 0.9758 - val_loss: 1.2001 - val_accuracy: 0.7815
# Epoch 29/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.0731 - accuracy: 0.9743 - val_loss: 1.9618 - val_accuracy: 0.7103
# Epoch 30/30
# 107/107 [==============================] - 184s 2s/step - loss: 0.0709 - accuracy: 0.9755 - val_loss: 1.3403 - val_accuracy: 0.7465

# %%
# Plot training and validation loss and accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(history_lcc.history['accuracy'], label='Training Accuracy')
plt.plot(history_lcc.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.subplot(1, 2, 1)
plt.plot(history_lcc.history['loss'], label='Training Loss')
plt.plot(history_lcc.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.show()

# %%
# Evaluate the model and compute metrics
predictions = model_lcc.predict(test_lcc_dataset)
predicted_labels = tf.argmax(predictions, axis=1).numpy()
true_labels = []
for _, labels in test_lcc_dataset:
    true_labels.extend(labels.numpy())

# Generate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
ConfusionMatrixDisplay(conf_matrix, display_labels=list(lcc_label_mapping.keys())).plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# Generate classification report
print("Classification Report:")
print(classification_report(
    true_labels,
    predicted_labels,
    target_names=list(lcc_label_mapping.keys()),
    zero_division=1  # Sets undefined metrics to 1 instead of raising warnings
))
# Out:
# 27/27 [==============================] - 12s 387ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
# Asian - East and Southeast       0.73      0.69      0.71       276
#              Asian - South       0.89      0.78      0.83       320
#                      White       0.64      0.77      0.70       260
#
#                   accuracy                           0.75       856
#                  macro avg       0.75      0.75      0.74       856
#               weighted avg       0.76      0.75      0.75       856

# %% [markdown]
# ### LCC/RCC pairs

# %%
# Split into train/test datasets
train_filepaths, test_filepaths, train_labels, test_labels = train_test_split(
    valid_filepaths, labels, test_size=0.2, stratify=labels, random_state=42
)

# Resample only the training dataset
class_groups = {label: [] for label in set(train_labels)}
for filepath_pair, label in zip(train_filepaths, train_labels):
    class_groups[label].append(filepath_pair)

# Define target size for resampling
resampling_targets = {"White": 400, "Asian - South": 500}

# Balance each class
balanced_train_filepaths = []
balanced_train_labels = []
for label, group in class_groups.items():
    target_size = resampling_targets.get(label, len(group))
    if len(group) > target_size:
        # Undersample majority classes
        sampled_group = random.sample(group, target_size)
    else:
        # Oversample minority classes
        sampled_group = resample(group, replace=True, n_samples=target_size, random_state=42)
    balanced_train_filepaths.extend(sampled_group)
    balanced_train_labels.extend([label] * target_size)

# Check the new distribution
print("New class distribution (train set):", Counter(balanced_train_labels))

# Check the new distribution
print("New training data distribution:")
print(Counter(balanced_train_labels))

print("Testing data distribution:")
print(Counter(test_labels))
# Out:
# New class distribution (train set): Counter({'Asian - East and Southeast': 503, 'Asian - South': 500, 'White': 400})
# New training data distribution:
# Counter({'Asian - East and Southeast': 503, 'Asian - South': 500, 'White': 400})
# Testing data distribution:
# Counter({'White': 177, 'Asian - East and Southeast': 126, 'Asian - South': 25})

# %%
# Convert labels to numeric format
def encode_labels(labels):
    label_mapping = {label: idx for idx, label in enumerate(set(labels))}
    encoded_labels = [label_mapping[label] for label in labels]
    return encoded_labels, label_mapping

encoded_train_labels, label_mapping = encode_labels(balanced_train_labels)
encoded_test_labels = [label_mapping[label] for label in test_labels]

# Prepare dataset for training
def create_pairs_dataset(filepaths, labels, augment=False):
    def load_image_pair(lcc_path, rcc_path, augment):
        lcc_image = tf.image.decode_png(tf.io.read_file(lcc_path), channels=1)
        rcc_image = tf.image.decode_png(tf.io.read_file(rcc_path), channels=1)
        lcc_image = tf.image.resize(lcc_image, [224, 224])
        rcc_image = tf.image.resize(rcc_image, [224, 224])

        if augment:
            # Apply horizontal flipping randomly
            lcc_image = tf.image.random_flip_left_right(lcc_image)
            rcc_image = tf.image.random_flip_left_right(rcc_image)

        combined_image = tf.concat([lcc_image, rcc_image], axis=-1)
        return combined_image

    images = [load_image_pair(lcc, rcc, augment) for lcc, rcc in filepaths]
    return tf.data.Dataset.from_tensor_slices((images, labels))

# Create datasets with augmentation for training only
train_dataset = create_pairs_dataset(balanced_train_filepaths, encoded_train_labels, augment=True).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = create_pairs_dataset(test_filepaths, encoded_test_labels, augment=False).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# 2025-01-17 17:33:31.369614: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 563175424 exceeds 10% of free system memory.

# %%
for image_batch, label_batch in train_dataset.take(1):
    print(f"Image batch shape: {image_batch.shape}")
    print(f"Label batch shape: {label_batch.shape}")
# Out:
# 2025-01-17 17:33:58.405398: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 563175424 exceeds 10% of free system memory.
# Image batch shape: (32, 224, 224, 2)
# Label batch shape: (32,)

# %%
for image_batch, label_batch in train_dataset.shuffle(1000).take(1):  # Shuffle before taking samples
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(tf.squeeze(image_batch[i][:, :, 0].numpy()), cmap="gray")
        label = list(label_mapping.keys())[list(label_mapping.values()).index(label_batch[i].numpy())]
        plt.title(f"Label: {label}")
        plt.axis("off")
    plt.show()
# Out:
# 2025-01-17 17:33:58.911520: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 563175424 exceeds 10% of free system memory.

# %%
# Build ResNet50 model with preprocessing for 2-channel input
input_layer = Input(shape=(224, 224, 2))

# Convert 2 channels to 3 channels to fit ResNet requirements
processed_input = Conv2D(3, (1, 1), activation='linear')(input_layer)

# Load ResNet50 without pre-trained weights
base_model = ResNet50(weights=None, include_top=False, input_tensor=processed_input)

# Add custom layers on top of ResNet50
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(len(label_mapping), activation='softmax')(x)

# Create the final model
model = Model(inputs=input_layer, outputs=output)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=30,
    # callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)]
)
# Out:
# 2025-01-17 17:34:02.703069: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 563175424 exceeds 10% of free system memory.
# Epoch 1/30
# 44/44 [==============================] - 100s 2s/step - loss: 3.8442 - accuracy: 0.7042 - val_loss: 10122452.0000 - val_accuracy: 0.5396
# Epoch 2/30
# 44/44 [==============================] - 74s 2s/step - loss: 2.9171 - accuracy: 0.1882 - val_loss: 2122.6921 - val_accuracy: 0.5396
# Epoch 3/30
# 44/44 [==============================] - 74s 2s/step - loss: 1.6082 - accuracy: 0.2609 - val_loss: 1.6228 - val_accuracy: 0.5396
# Epoch 4/30
# 44/44 [==============================] - 74s 2s/step - loss: 1.6549 - accuracy: 0.2559 - val_loss: 255.7675 - val_accuracy: 0.5396
# Epoch 5/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.3429 - accuracy: 0.5388 - val_loss: 1.7258 - val_accuracy: 0.5396
# Epoch 6/30
# 44/44 [==============================] - 73s 2s/step - loss: 2.0918 - accuracy: 0.1262 - val_loss: 1.0813 - val_accuracy: 0.5396
# Epoch 7/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.1194 - accuracy: 0.2609 - val_loss: 1.1091 - val_accuracy: 0.1189
# Epoch 8/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.1293 - accuracy: 0.2659 - val_loss: 1.1386 - val_accuracy: 0.0762
# Epoch 9/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.1221 - accuracy: 0.2744 - val_loss: 1.1402 - val_accuracy: 0.0762
# Epoch 10/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1193 - accuracy: 0.2587 - val_loss: 1.1380 - val_accuracy: 0.0762
# Epoch 11/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1209 - accuracy: 0.2922 - val_loss: 1.1372 - val_accuracy: 0.0762
# Epoch 12/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.1172 - accuracy: 0.2922 - val_loss: 1.1368 - val_accuracy: 0.0762
# Epoch 13/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1156 - accuracy: 0.3150 - val_loss: 1.1384 - val_accuracy: 0.0762
# Epoch 14/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1262 - accuracy: 0.2972 - val_loss: 1.1378 - val_accuracy: 0.0762
# Epoch 15/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1189 - accuracy: 0.2687 - val_loss: 1.1364 - val_accuracy: 0.0762
# Epoch 16/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1128 - accuracy: 0.3507 - val_loss: 1.1372 - val_accuracy: 0.0762
# Epoch 17/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1115 - accuracy: 0.3949 - val_loss: 1.1395 - val_accuracy: 0.0762
# Epoch 18/30
# 44/44 [==============================] - 71s 2s/step - loss: 1.1094 - accuracy: 0.4091 - val_loss: 1.1414 - val_accuracy: 0.0762
# Epoch 19/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1079 - accuracy: 0.3792 - val_loss: 1.1436 - val_accuracy: 0.0762
# Epoch 20/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1080 - accuracy: 0.3934 - val_loss: 1.1467 - val_accuracy: 0.0762
# Epoch 21/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1073 - accuracy: 0.3635 - val_loss: 1.1537 - val_accuracy: 0.0762
# Epoch 22/30
# 44/44 [==============================] - 71s 2s/step - loss: 1.1218 - accuracy: 0.3500 - val_loss: 1.1496 - val_accuracy: 0.0762
# Epoch 23/30
# 44/44 [==============================] - 71s 2s/step - loss: 1.1229 - accuracy: 0.3877 - val_loss: 1.1429 - val_accuracy: 0.0762
# Epoch 24/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1288 - accuracy: 0.3329 - val_loss: 1.1459 - val_accuracy: 0.0762
# Epoch 25/30
# 44/44 [==============================] - 73s 2s/step - loss: 0.8995 - accuracy: 0.6215 - val_loss: 1.0200 - val_accuracy: 0.5396
# Epoch 26/30
# 44/44 [==============================] - 72s 2s/step - loss: 3.6928 - accuracy: 0.4783 - val_loss: 123.4667 - val_accuracy: 0.0762
# Epoch 27/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.1325 - accuracy: 0.1853 - val_loss: 1.1054 - val_accuracy: 0.3841
# Epoch 28/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.0998 - accuracy: 0.3585 - val_loss: 1.1066 - val_accuracy: 0.3841
# Epoch 29/30
# 44/44 [==============================] - 73s 2s/step - loss: 1.0996 - accuracy: 0.3585 - val_loss: 1.1077 - val_accuracy: 0.3841
# Epoch 30/30
# 44/44 [==============================] - 72s 2s/step - loss: 1.0995 - accuracy: 0.3585 - val_loss: 1.1089 - val_accuracy: 0.3841

# %%
# Plot training and validation loss and accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Over Epochs')

plt.show()

# %%
# Evaluate the model and compute metrics
predictions = model.predict(test_dataset)
predicted_labels = tf.argmax(predictions, axis=1).numpy()
true_labels = []
for _, labels in test_dataset:
    true_labels.extend(labels.numpy())

# Generate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
ConfusionMatrixDisplay(conf_matrix, display_labels=list(label_mapping.keys())).plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# Generate classification report
print("Classification Report:")
print(classification_report(
    true_labels,
    predicted_labels,
    target_names=list(label_mapping.keys()),
    zero_division=1  # Sets undefined metrics to 1 instead of raising warnings
))
# Out:
# 11/11 [==============================] - 4s 356ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
# Asian - East and Southeast       0.38      1.00      0.56       126
#              Asian - South       1.00      0.00      0.00        25
#                      White       1.00      0.00      0.00       177
#
#                   accuracy                           0.38       328
#                  macro avg       0.79      0.33      0.19       328
#               weighted avg       0.76      0.38      0.21       328

# %%
# Analyze predicted and true label distributions

print("Predicted label distribution:", Counter(predicted_labels))
print("True label distribution:", Counter(true_labels)) # Test label
# Out:
# Predicted label distribution: Counter({2: 316, 1: 280, 0: 260})
# True label distribution: Counter({1: 320, 0: 276, 2: 260})
