# %%
import pandas as pd
import numpy as np
import os
import pydicom
from PIL import Image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# %%
# Load the CSV file
data_path = '/mnt/win_share/GitHub/AI-ethnicity-med-image/data/axial_lung_ct_images.csv'
df = pd.read_csv(data_path)

# %%
# Convert any Windows-style paths to Unix-style paths
df['File Location'] = df['File Location'].apply(lambda x: x.replace("\\", "/"))

# %%
# Group by 'Subject ID' to handle multiple images per patient
grouped = df.groupby('Subject ID')

# Randomly select one image per patient
df_single_image_per_patient = grouped.apply(lambda x: x.sample(1, random_state=42)).reset_index(drop=True)

# Label mapping for converting race categories to integers
label_mapping = {
    "White": 0,
    "Black or African-American": 1,
    "Asian": 2,
    "American Indian or Alaskan Native": 3,
    "Native Hawaiian or Other Pacific Islander": 4
}

# Convert the 'Patient Race' to integer labels
df_single_image_per_patient['Race_Label'] = df_single_image_per_patient['Patient Race'].map(label_mapping)

# %%
num_patients = df_single_image_per_patient['Subject ID'].nunique()
num_images = len(df_single_image_per_patient)

# Print the results
print(f"Number of unique patients: {num_patients}")
print(f"Number of images after selecting one per patient: {num_images}")
# Out:
# Number of unique patients: 15639
# Number of images after selecting one per patient: 15639

# %%
# Train-validation split
X_train, X_val, y_train, y_val = train_test_split(
    df_single_image_per_patient['File Location'],
    df_single_image_per_patient['Race_Label'],
    test_size=0.2,
    stratify=df_single_image_per_patient['Race_Label'],
    random_state=42
)

# %%
# Combine train data into a DataFrame for resampling
train_df = pd.DataFrame({
    'File Location': X_train, 
    'Race_Label': y_train})

# %%
# Map integer labels back to race names
race_mapping = {v: k for k, v in label_mapping.items()}
train_df['Patient Race'] = train_df['Race_Label'].map(race_mapping)

# %%
# Downsampling and Upsampling Strategy
desired_samples = {
    "White": 2000,  # Downsample to 2000
    "Black or African-American": 1135,  # Upsample
    "Asian": 1135,  # Upsample
    "American Indian or Alaskan Native": 1135,  # Upsample
    "Native Hawaiian or Other Pacific Islander": 1135  # Upsample
}

# %%
# Resampling on the training set only
resampled_train_df = pd.DataFrame()

for race, target_count in desired_samples.items():
    # Filter data for the current race
    race_df = train_df[train_df['Patient Race'] == race]
    print(f"\nProcessing race '{race}': {len(race_df)} available samples, target: {target_count}")

    # Resample
    if len(race_df) > target_count:
        # Downsample
        print(f"Downsampling to {target_count}")
        resampled_train_df = pd.concat([resampled_train_df, race_df.sample(target_count, random_state=42)])
    else:
        # Upsample
        print(f"Upsampling to {target_count} (replace=True)")
        resampled_train_df = pd.concat([resampled_train_df, race_df.sample(target_count, replace=True, random_state=42)])

# Reset index for the resampled DataFrame
resampled_train_df = resampled_train_df.reset_index(drop=True)

print("\nResampling complete.")
print(f"Total resampled data: {len(resampled_train_df)} samples")
# Out:
# Processing race 'White': 11548 available samples, target: 2000
# Downsampling to 2000
#
# Processing race 'Black or African-American': 467 available samples, target: 1135
# Upsampling to 1135 (replace=True)
#
# Processing race 'Asian': 393 available samples, target: 1135
# Upsampling to 1135 (replace=True)
#
# Processing race 'American Indian or Alaskan Native': 38 available samples, target: 1135
# Upsampling to 1135 (replace=True)
#
# Processing race 'Native Hawaiian or Other Pacific Islander': 65 available samples, target: 1135
# Upsampling to 1135 (replace=True)
#
# Resampling complete.
# Total resampled data: 6540 samples

# %%
# Check class distribution
print("Class distribution after resampling:")
print(resampled_train_df['Patient Race'].value_counts())
# Out:
# Class distribution after resampling:
# Patient Race
# White                                        2000
# Black or African-American                    1135
# Asian                                        1135
# American Indian or Alaskan Native            1135
# Native Hawaiian or Other Pacific Islander    1135
# Name: count, dtype: int64

# %%
# Change to current directory
os.chdir('/media/yu-tingtseng_sa/16TB IronWolf Pro/Data/NLST/Radiology CT Images/manifest-NLST_allCT')
print(os.getcwd())
# Out:
# /media/yu-tingtseng_sa/16TB IronWolf Pro/Data/NLST/Radiology CT Images/manifest-NLST_allCT

# %%
# Preprocess images for model input
def preprocess_images(file_paths, labels):
    image_data = []
    processed_labels = []
    
    # Ensure only one image per patient (process the first DICOM file found)
    for file_path, label in zip(file_paths, labels):
        dicom_folder = file_path  # Path to the folder containing DICOM images
        dicom_files = [f for f in os.listdir(dicom_folder) if f.endswith('.dcm')]  # List DICOM files
        
        if dicom_files:
            dicom_file = dicom_files[0]  # Select the first DICOM file only
            dicom_path = os.path.join(dicom_folder, dicom_file)
            ds = pydicom.dcmread(dicom_path)  # Read the DICOM file
            img_array = ds.pixel_array  # Extract pixel array

            # Normalize the image
            img_array = img_array / np.max(img_array)  # Normalize to [0, 1]

            # Resize the image
            img = Image.fromarray(img_array)  # Convert to PIL image
            img = img.resize((512, 512))  # Resize to 512x512 pixels
            img_array_resized = np.array(img)  # Convert back to numpy array

            # Convert grayscale image to 3-channel RGB by repeating the single channel 3 times
            img_array_rgb = np.stack([img_array_resized] * 3, axis=-1)

            image_data.append(img_array_rgb)
            processed_labels.append(label)  # Append the corresponding label
    
    return np.array(image_data), np.array(processed_labels)

# %%
# Preprocess images for training and validation sets (ensure 1 image per patient)
X_train_images, y_train_labels = preprocess_images(resampled_train_df['File Location'], resampled_train_df['Race_Label'])
X_val_images, y_val_labels = preprocess_images(X_val, y_val)

# %%
# Check the number of images
num_train_images = X_train_images.shape[0]
num_val_images = X_val_images.shape[0]

print(f"Number of training images: {num_train_images}")
print(f"Number of validation images: {num_val_images}")
print(f"Number of training labels: {len(y_train_labels)}")
print(f"Number of validation labels: {len(y_val_labels)}")
# Out:
# Number of training images: 6540
# Number of validation images: 3128
# Number of training labels: 6540
# Number of validation labels: 3128

# %%
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: []
# 2024-11-22 12:37:25.613621: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 12:37:25.613854: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 12:37:25.696147: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Load the pre-trained EfficientNetB0 model without the top layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(512, 512, 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of the pre-trained model
x = base_model.output
x = Flatten()(x)  # Flatten the output
x = Dense(128, activation='relu')(x)  # Fully connected layer
output = Dense(len(label_mapping), activation='softmax')(x)  # Output layer with softmax activation for multiclass classification

# %%
# Create the complete model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the generator
history = model.fit(X_train_images, 
                    y_train_labels, 
                    validation_data=(X_val_images, y_val_labels), 
                    epochs=50, 
                    batch_size=32)

# Save the model
# model.save('ethnicity_classification_model.h5')
# Out:
# Epoch 1/50
# 2024-11-22 12:37:28.758689: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 20573061120 exceeds 10% of free system memory.
# 205/205 [==============================] - ETA: 0s - loss: 1.4552 - accuracy: 0.4385
# 2024-11-22 12:46:34.731550: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 9839837184 exceeds 10% of free system memory.
# 205/205 [==============================] - 781s 4s/step - loss: 1.4552 - accuracy: 0.4385 - val_loss: 1.4404 - val_accuracy: 0.2430
# Epoch 2/50
# 205/205 [==============================] - 806s 4s/step - loss: 1.1012 - accuracy: 0.5306 - val_loss: 1.8009 - val_accuracy: 0.1432
# Epoch 3/50
# 205/205 [==============================] - 807s 4s/step - loss: 1.0249 - accuracy: 0.5700 - val_loss: 0.8209 - val_accuracy: 0.7206
# Epoch 4/50
# 205/205 [==============================] - 805s 4s/step - loss: 0.9740 - accuracy: 0.5985 - val_loss: 1.1659 - val_accuracy: 0.4850
# Epoch 5/50
# 205/205 [==============================] - 725s 4s/step - loss: 0.9164 - accuracy: 0.6283 - val_loss: 0.6166 - val_accuracy: 0.8488
# Epoch 6/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.8304 - accuracy: 0.6746 - val_loss: 0.8766 - val_accuracy: 0.6515
# Epoch 7/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.8120 - accuracy: 0.6693 - val_loss: 1.0739 - val_accuracy: 0.5738
# Epoch 8/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.8074 - accuracy: 0.6817 - val_loss: 0.7213 - val_accuracy: 0.7535
# Epoch 9/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.7481 - accuracy: 0.7165 - val_loss: 0.5904 - val_accuracy: 0.8427
# Epoch 10/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.7306 - accuracy: 0.7243 - val_loss: 0.6576 - val_accuracy: 0.8242
# Epoch 11/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.7199 - accuracy: 0.7297 - val_loss: 0.6571 - val_accuracy: 0.7999
# Epoch 12/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.6754 - accuracy: 0.7446 - val_loss: 0.9963 - val_accuracy: 0.5959
# Epoch 13/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.6479 - accuracy: 0.7586 - val_loss: 0.9696 - val_accuracy: 0.6503
# Epoch 14/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.6631 - accuracy: 0.7434 - val_loss: 0.4215 - val_accuracy: 0.8830
# Epoch 15/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.6505 - accuracy: 0.7580 - val_loss: 0.8349 - val_accuracy: 0.6691
# Epoch 16/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.6217 - accuracy: 0.7705 - val_loss: 0.5511 - val_accuracy: 0.8315
# Epoch 17/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.5782 - accuracy: 0.7946 - val_loss: 0.9228 - val_accuracy: 0.6506
# Epoch 18/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.5541 - accuracy: 0.8050 - val_loss: 1.0730 - val_accuracy: 0.4965
# Epoch 19/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.5966 - accuracy: 0.7804 - val_loss: 0.6981 - val_accuracy: 0.7442
# Epoch 20/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.5393 - accuracy: 0.8096 - val_loss: 0.8088 - val_accuracy: 0.7193
# Epoch 21/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.5131 - accuracy: 0.8225 - val_loss: 0.8090 - val_accuracy: 0.6957
# Epoch 22/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.5139 - accuracy: 0.8188 - val_loss: 0.6178 - val_accuracy: 0.8107
# Epoch 23/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.5458 - accuracy: 0.8041 - val_loss: 0.9902 - val_accuracy: 0.6042
# Epoch 24/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.5015 - accuracy: 0.8283 - val_loss: 0.6835 - val_accuracy: 0.8027
# Epoch 25/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.4800 - accuracy: 0.8338 - val_loss: 0.6687 - val_accuracy: 0.8063
# Epoch 26/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.5165 - accuracy: 0.8119 - val_loss: 1.0373 - val_accuracy: 0.5694
# Epoch 27/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.4471 - accuracy: 0.8529 - val_loss: 2.3247 - val_accuracy: 0.1231
# Epoch 28/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.4964 - accuracy: 0.8168 - val_loss: 0.9771 - val_accuracy: 0.5678
# Epoch 29/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.4349 - accuracy: 0.8528 - val_loss: 0.9331 - val_accuracy: 0.6672
# Epoch 30/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.4357 - accuracy: 0.8547 - val_loss: 0.7809 - val_accuracy: 0.6605
# Epoch 31/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.4344 - accuracy: 0.8498 - val_loss: 0.5502 - val_accuracy: 0.8402
# Epoch 32/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.4181 - accuracy: 0.8595 - val_loss: 1.2195 - val_accuracy: 0.5109
# Epoch 33/50
# 205/205 [==============================] - 712s 3s/step - loss: 0.4440 - accuracy: 0.8343 - val_loss: 1.0002 - val_accuracy: 0.5655
# Epoch 34/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.4399 - accuracy: 0.8433 - val_loss: 0.4887 - val_accuracy: 0.8699
# Epoch 35/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.3870 - accuracy: 0.8731 - val_loss: 1.0910 - val_accuracy: 0.5480
# Epoch 36/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.3967 - accuracy: 0.8680 - val_loss: 0.4461 - val_accuracy: 0.8808
# Epoch 37/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.4094 - accuracy: 0.8566 - val_loss: 0.6713 - val_accuracy: 0.7554
# Epoch 38/50
# 205/205 [==============================] - 713s 3s/step - loss: 0.3787 - accuracy: 0.8751 - val_loss: 0.5555 - val_accuracy: 0.8120
# Epoch 39/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.3836 - accuracy: 0.8653 - val_loss: 0.6893 - val_accuracy: 0.7561
# Epoch 40/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.3860 - accuracy: 0.8682 - val_loss: 0.5071 - val_accuracy: 0.8370
# Epoch 41/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.3815 - accuracy: 0.8709 - val_loss: 0.7318 - val_accuracy: 0.7551
# Epoch 42/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.3518 - accuracy: 0.8820 - val_loss: 0.6136 - val_accuracy: 0.8012
# Epoch 43/50
# 205/205 [==============================] - 715s 3s/step - loss: 0.3688 - accuracy: 0.8711 - val_loss: 0.9501 - val_accuracy: 0.6132
# Epoch 44/50
# 205/205 [==============================] - 714s 3s/step - loss: 0.3482 - accuracy: 0.8812 - val_loss: 0.4536 - val_accuracy: 0.8670
# Epoch 45/50
# 205/205 [==============================] - 715s 3s/step - loss: 0.3716 - accuracy: 0.8693 - val_loss: 0.8819 - val_accuracy: 0.6586
# Epoch 46/50
# 205/205 [==============================] - 715s 3s/step - loss: 0.3540 - accuracy: 0.8792 - val_loss: 0.3806 - val_accuracy: 0.8993
# Epoch 47/50
# 205/205 [==============================] - 715s 3s/step - loss: 0.3589 - accuracy: 0.8728 - val_loss: 0.6477 - val_accuracy: 0.7689
# Epoch 48/50
# 205/205 [==============================] - 715s 3s/step - loss: 0.3214 - accuracy: 0.8937 - val_loss: 0.4436 - val_accuracy: 0.8686
# Epoch 49/50
# 205/205 [==============================] - 716s 3s/step - loss: 0.3366 - accuracy: 0.8861 - val_loss: 0.6206 - val_accuracy: 0.7753
# Epoch 50/50
# 205/205 [==============================] - 746s 4s/step - loss: 0.3345 - accuracy: 0.8872 - val_loss: 0.6601 - val_accuracy: 0.7992

# %%
# Plot training & validation accuracy
plt.style.use('default')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Make predictions on the validation set
y_pred = model.predict(X_val_images)

# Convert predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
# Out:
# 2024-11-22 22:38:40.495434: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 9839837184 exceeds 10% of free system memory.
# 98/98 [==============================] - 215s 2s/step

# %%
# Create a confusion matrix
cm = confusion_matrix(y_val_labels, y_pred_labels)

cma = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Define race labels
race_labels = ['W', 'B/AF', 'A', 'AI/AN', 'NH/PA']

# Calculate accuracy
accuracy = accuracy_score(y_val_labels, y_pred_labels)
print(f"Accuracy: {accuracy:.4f}")

# Plot the confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cma, annot=True, fmt='.2f', cmap='Blues', xticklabels=race_labels, yticklabels=race_labels)
plt.xlabel('Predicted Race')
plt.ylabel('True Race')
plt.title(f'Confusion Matrix - Ethnicity Classification (Accuracy: {accuracy:.2f})')
plt.show()
# Out:
# Accuracy: 0.7992

# %%
# Print a detailed classification report
print("Classification Report:")
print(classification_report(y_val_labels, y_pred_labels, target_names=label_mapping.keys(), zero_division=1))
# Out:
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                                     White       0.97      0.82      0.89      2887
#                 Black or African-American       0.17      0.41      0.24       117
#                                     Asian       0.24      0.85      0.38        98
#         American Indian or Alaskan Native       0.00      0.00      1.00        10
# Native Hawaiian or Other Pacific Islander       0.12      0.12      0.12        16
#
#                                  accuracy                           0.80      3128
#                                 macro avg       0.30      0.44      0.52      3128
#                              weighted avg       0.91      0.80      0.84      3128
